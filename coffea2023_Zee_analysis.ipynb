# %% [markdown]
# # PHYSLITE columnar Zee analysis using coffea2023

# %% [markdown]
# <b>Package imports and versions</b>

# %%
from pathlib import Path
import warnings

import hist
import awkward as ak
import coffea
import uproot
from coffea.nanoevents import NanoEventsFactory, PHYSLITESchema
import dask_awkward as dak

# %%
print(f"coffea version: {coffea.__version__}")
print(f"awkward version: {ak.__version__}")
print(f"uproot version: {uproot.__version__}")
print(f"hist version: {hist.__version__}")
# Out:
# coffea version: 2023.10.0rc1
# awkward version: 2.5.1
# uproot version: 5.1.2
# hist version: 2.7.2

# %% [markdown]
# <b>Input PHYSLITE dataset</b>
# - `mc20_13TeV.700320.Sh_2211_Zee_maxHTpTV2_BFilter.deriv.DAOD_PHYSLITE.e8351_s3681_r13167_p5855`
# - 330 files / 497 GB / 35.6Mevts

# %%
local_input_path = "/data_ceph/kyungeon/PHYSLITE/"
dataset = "mc20_13TeV.700320.Sh_2211_Zee_maxHTpTV2_BFilter.deriv.DAOD_PHYSLITE.e8351_s3681_r13167_p5855"
# dataset = "mc20_13TeV.700320.Sh_2211_Zee_maxHTpTV2_BFilter.deriv.DAOD_PHYSLITE.e8351_s3681_r13167_p5631"
files = list(Path(local_input_path+dataset).glob("*root.1"))
print(f"Total #files = {len(files)}")

files = files[:30]
# Out:
# Total #files = 330

# %%
len(files)
# Out:
# 30

# %% [markdown]
# <b>Load dask awkward arrays with coffea PHYSLITEschema</b>

# %%
def get_events(files):
    factory = NanoEventsFactory.from_root(
        {fi:"CollectionTree" for fi in files},
        schemaclass=PHYSLITESchema,
        permit_dask=True
    )

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        events = factory.events()
    
    return events

# %% [markdown]
# <b>Event selection</b>
# - 2 electrons
# - Opposite charge

# %%
def event_selection(events):
    cut_2el = ak.num(events.Electrons, axis=1) == 2
    cut_charge = ak.sum(events.Electrons.charge, axis=1) == 0

    selections = cut_2el & cut_charge
    
    return events[selections]

# %% [markdown]
# <b>Reconstruct Z</b>

# %%
def reconstruct_z(events):
    el_pair = ak.combinations(events.Electrons, 2)
    el1, el2 = ak.unzip(el_pair)
    el_pair["p4"] = el1 + el2
    return el_pair.p4

# %% [markdown]
# <b>Define histograms</b>

# %%
import hist.dask as dah

def get_histograms():
    return dah.Hist(
        dah.Hist.new.Reg(100, 0, 200_000, name="z_mass", label=r"$m_{ee}$ [GeV]"),
        storage="weight"
    )

# %% [markdown]
# <b>Build analysis</b>

# %%
evts = get_events(files)

selected_evts = event_selection(evts)

el_pair_p4 = reconstruct_z(selected_evts)

h = get_histograms()

output = h.fill(z_mass=ak.flatten(el_pair_p4.mass))
# output = h.fill(z_mass=ak.flatten(selected_evts.Electrons.pt))

# %% [markdown]
# Columns for the analysis

# %%
dak.necessary_columns(output)
# Out:
# {'from-uproot-70211f49e0bf1cc9474f0326ee7efe10': frozenset({'AnalysisElectronsAuxDyn.charge',
#             'AnalysisElectronsAuxDyn.eta',
#             'AnalysisElectronsAuxDyn.m',
#             'AnalysisElectronsAuxDyn.phi',
#             'AnalysisElectronsAuxDyn.pt',
#             'AnalysisElectronsAuxDyn.trackParticleLinks'})}

# %% [markdown]
# dask task graph

# %%
output.visualize(optimize_graph=True)
# el_pair_p4.visualize(optimize_graph=True)
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'dagre', 'rankDir': 'BT', 'nodeSep': 10, 'edgeSep': 10, 'spacingFact…

# %% [markdown]
# <b>Get results</b>
#
# Set up local dask cluster

# %%
from dask.distributed import LocalCluster, Client
cluster = LocalCluster(n_workers=30, threads_per_worker=1)
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:4797' processes=30 threads=30, memory=62.54 GiB>

# %% [markdown]
# Compute dask graphs

# %%
out_hist = output.compute()
# Out:
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# 2023-12-16 22:33:18,563 - distributed.worker - WARNING - Compute Failed
# Key:       ('hist-on-block-f692ce7396b0cef570d3cef22623641d', 19)
# Function:  subgraph_callable-beda63a5-e6e3-4860-ab6b-299dabc5
# args:      ('1', '0', 'Electrons', ('/data_ceph/kyungeon/PHYSLITE/mc20_13TeV.700320.Sh_2211_Zee_maxHTpTV2_BFilter.deriv.DAOD_PHYSLITE.e8351_s3681_r13167_p5855/DAOD_PHYSLITE.34869232._000020.pool.root.1', 'CollectionTree', 0, 1, False))
# kwargs:    {}
# Exception: "TypeError('Awkward Array does not support arrays with object dtypes.\\n\\nThis error occurred while calling\\n\\n    ak.concatenate(\\n        [array([<STLVector [] at 0x7f0f87ee2d00>], dtype=object), <Array [[[{...\\n    )')"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_dispatch.py:62, in dispatch()
#      61 try:
# ---> 62     next(gen_or_result)
#      63 except StopIteration as err:
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/operations/ak_concatenate.py:66, in concatenate()
#      65 # Implementation
# ---> 66 return _impl(arrays, axis, mergebool, highlevel, behavior, attrs)
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/operations/ak_concatenate.py:114, in _impl()
#     113 with HighLevelContext(behavior=behavior, attrs=attrs) as ctx:
# --> 114     content_or_others = ensure_same_backend(
#     115         *(
#     116             ctx.unwrap(
#     117                 x,
#     118                 allow_record=axis != 0,
#     119                 allow_unknown=False,
#     120                 primitive_policy="pass-through",
#     121             )
#     122             for x in arrays
#     123         )
#     124     )
#     126 contents = [x for x in content_or_others if isinstance(x, ak.contents.Content)]
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/operations/ak_concatenate.py:116, in <genexpr>()
#     113 with HighLevelContext(behavior=behavior, attrs=attrs) as ctx:
#     114     content_or_others = ensure_same_backend(
#     115         *(
# --> 116             ctx.unwrap(
#     117                 x,
#     118                 allow_record=axis != 0,
#     119                 allow_unknown=False,
#     120                 primitive_policy="pass-through",
#     121             )
#     122             for x in arrays
#     123         )
#     124     )
#     126 contents = [x for x in content_or_others if isinstance(x, ak.contents.Content)]
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_layout.py:146, in unwrap()
#     144 self.update(obj)
# --> 146 return to_layout_impl(
#     147     obj,
#     148     allow_record=allow_record,
#     149     allow_unknown=allow_unknown,
#     150     none_policy=none_policy,
#     151     use_from_iter=use_from_iter,
#     152     primitive_policy=primitive_policy,
#     153     string_policy=string_policy,
#     154     regulararray=regulararray,
#     155 )
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/operations/ak_to_layout.py:177, in _impl()
#     176 elif numpy.is_own_array(obj):
# --> 177     promoted_layout = ak.operations.from_numpy(
#     178         obj,
#     179         regulararray=regulararray,
#     180         recordarray=True,
#     181         highlevel=False,
#     182     )
#     183     return _handle_array_like(
#     184         obj, promoted_layout, primitive_policy=primitive_policy
#     185     )
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_dispatch.py:39, in dispatch()
#      38 with OperationErrorContext(name, args, kwargs):
# ---> 39     gen_or_result = func(*args, **kwargs)
#      40     if isgenerator(gen_or_result):
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/operations/ak_from_numpy.py:55, in from_numpy()
#      21 """
#      22 Args:
#      23     array (np.ndarray): The NumPy array to convert into an Awkward Array.
#    (...)
#      52 See also #ak.to_numpy and #ak.from_cupy.
#      53 """
#      54 return wrap_layout(
# ---> 55     from_arraylib(array, regulararray, recordarray),
#      56     highlevel=highlevel,
#      57     behavior=behavior,
#      58 )
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_layout.py:347, in from_arraylib()
#     346 if array.dtype == np.dtype("O"):
# --> 347     raise TypeError("Awkward Array does not support arrays with object dtypes.")
#     349 if isinstance(array, numpy.ma.MaskedArray):
#
# TypeError: Awkward Array does not support arrays with object dtypes.
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /home/kyungeon/code/columnar_PHYSLITE_analyses/coffea2023_Zee_analysis.ipynb Cell 26 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Btop1/home/kyungeon/code/columnar_PHYSLITE_analyses/coffea2023_Zee_analysis.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> out_hist = output.compute()
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/dask/base.py:342, in DaskMethodsMixin.compute(self, **kwargs)
#     318 def compute(self, **kwargs):
#     319     """Compute this dask collection
#     320
#     321     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     340     dask.compute
#     341     """
# --> 342     (result,) = compute(self, traverse=False, **kwargs)
#     343     return result
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/dask/base.py:628, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     625     postcomputes.append(x.__dask_postcompute__())
#     627 with shorten_traceback():
# --> 628     results = schedule(dsk, keys, **kwargs)
#     630 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/uproot/_dask.py:1106, in __call__()
#    1100     start, stop = min((i_step_or_start * events_per_step), num_entries), min(
#    1101         (i_step_or_start + 1) * events_per_step, num_entries
#    1102     )
#    1104 assert start <= stop
# -> 1106 return self.read_tree(ttree, start, stop)
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/uproot/_dask.py:924, in read_tree()
#     920 # If reading this buffer loads a permitted key, read from the tree
#     921 # We might not have _all_ keys if e.g. buffer A requires one
#     922 # but not two of the keys required for buffer B
#     923 if all(k in self.common_keys for k in keys_for_buffer):
# --> 924     container[buffer_key] = mapping[buffer_key]
#     925 # Otherwise, introduce a placeholder
#     926 else:
#     927     container[buffer_key] = awkward.typetracer.PlaceholderArray(
#     928         nplike=nplike,
#     929         shape=(awkward.typetracer.unknown_length,),
#     930         dtype=dtype,
#     931     )
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/coffea/nanoevents/factory.py:121, in __getitem__()
#     120 def __getitem__(self, index):
# --> 121     return self._mapping[self._func(index)]
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/coffea/nanoevents/mapping/base.py:98, in __getitem__()
#      93         self._access_log.append(handle_name)
#      94     handle = self.get_column_handle(
#      95         self._column_source(uuid, treepath), handle_name
#      96     )
#      97     stack.append(
# ---> 98         self.extract_column(
#      99             handle, start, stop, use_ak_forth=self._use_ak_forth
#     100         )
#     101     )
#     102 elif node.startswith("!"):
#     103     tname = node[1:]
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/coffea/nanoevents/mapping/uproot.py:161, in extract_column()
#     159 interp = columnhandle.interpretation
#     160 interp._forth = use_ak_forth
# --> 161 return columnhandle.array(
#     162     interp,
#     163     entry_start=start,
#     164     entry_stop=stop,
#     165     decompression_executor=uproot.source.futures.TrivialExecutor(),
#     166     interpretation_executor=uproot.source.futures.TrivialExecutor(),
#     167 )
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:1821, in array()
#    1818                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#    1820 interp_options = {"ak_add_doc": ak_add_doc}
# -> 1821 _ranges_or_baskets_to_arrays(
#    1822     self,
#    1823     ranges_or_baskets,
#    1824     branchid_interpretation,
#    1825     entry_start,
#    1826     entry_stop,
#    1827     decompression_executor,
#    1828     interpretation_executor,
#    1829     library,
#    1830     arrays,
#    1831     False,
#    1832     interp_options,
#    1833 )
#    1835 _fix_asgrouped(
#    1836     arrays,
#    1837     expression_context,
#    (...)
#    1841     ak_add_doc,
#    1842 )
#    1844 if array_cache is not None:
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:3149, in _ranges_or_baskets_to_arrays()
#    3146     pass
#    3148 elif isinstance(obj, tuple) and len(obj) == 3:
# -> 3149     uproot.source.futures.delayed_raise(*obj)
#    3151 else:
#    3152     raise AssertionError(obj)
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/uproot/source/futures.py:38, in delayed_raise()
#      34 def delayed_raise(exception_class, exception_value, traceback):
#      35     """
#      36     Raise an exception from a background thread on the main thread.
#      37     """
# ---> 38     raise exception_value.with_traceback(traceback)
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:3118, in basket_to_array()
#    3115 basket = None
#    3117 if len(basket_arrays) == branchid_num_baskets[branch.cache_key]:
# -> 3118     arrays[branch.cache_key] = interpretation.final_array(
#    3119         basket_arrays,
#    3120         entry_start,
#    3121         entry_stop,
#    3122         branch.entry_offsets,
#    3123         library,
#    3124         branch,
#    3125         interp_options,
#    3126     )
#    3127     # no longer needed, save memory
#    3128     basket_arrays.clear()
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/uproot/interpretation/objects.py:424, in final_array()
#     422     output = awkward.concatenate(trimmed, mergebool=False, highlevel=False)
#     423 else:
# --> 424     output = numpy.concatenate(trimmed)
#     426 self.hook_before_library_finalize(
#     427     basket_arrays=basket_arrays,
#     428     entry_start=entry_start,
#    (...)
#     433     output=output,
#     434 )
#     436 output = library.finalize(
#     437     output, branch, self, entry_start, entry_stop, options
#     438 )
#
# File <__array_function__ internals>:180, in concatenate()
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/highlevel.py:1527, in __array_function__()
#    1513 def __array_function__(self, func, types, args, kwargs):
#    1514     """
#    1515     Intercepts attempts to pass this Array to those NumPy functions other
#    1516     than universal functions that have an Awkward equivalent.
#    (...)
#    1525     See also #__array_ufunc__.
#    1526     """
# -> 1527     return ak._connect.numpy.array_function(
#    1528         func, types, args, kwargs, behavior=self._behavior, attrs=self._attrs
#    1529     )
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_connect/numpy.py:102, in array_function()
#     100 function = implemented.get(func)
#     101 if function is not None:
# --> 102     return function(*args, **kwargs)
#     103 # Use NumPy's implementation
#     104 else:
#     105     all_arguments = chain(args, kwargs.values())
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_connect/numpy.py:142, in ensure_valid_args()
#     138     names = ", ".join(provided_invalid_names)
#     139     raise TypeError(
#     140         f"Awkward NEP-18 overload was provided with unsupported argument(s): {names}"
#     141     )
# --> 142 return function(*args, **kwargs)
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_dispatch.py:70, in dispatch()
#      65     else:
#      66         raise AssertionError(
#      67             "high-level functions should only implement a single yield statement"
#      68         )
# ---> 70 return gen_or_result
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_errors.py:85, in __exit__()
#      78 try:
#      79     # Handle caught exception
#      80     if (
#      81         exception_type is not None
#      82         and issubclass(exception_type, Exception)
#      83         and self.primary() is self
#      84     ):
# ---> 85         self.handle_exception(exception_type, exception_value)
#      86 finally:
#      87     # Step out of the way so that another ErrorContext can become primary.
#      88     if self.primary() is self:
#
# File ~/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_errors.py:95, in handle_exception()
#      93     self.decorate_exception(cls, exception)
#      94 else:
# ---> 95     raise self.decorate_exception(cls, exception)
#
# TypeError: Awkward Array does not support arrays with object dtypes.
#
# This error occurred while calling
#
#     ak.concatenate(
#         [array([<STLVector [] at 0x7f0f87ee2d00>], dtype=object), <Array [[[{...
#     )
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))
# /home/kyungeon/.conda/envs/coffea2023/lib/python3.9/site-packages/awkward/_nplikes/array_module.py:271: RuntimeWarning: invalid value encountered in sqrt
#   return impl(*non_generic_value_promoted_args, **(kwargs or {}))

# %% [markdown]
# <b>Plot histgorams</b>

# %%
import mplhep as mpl
import matplotlib.pyplot as plt
plt.style.use(mpl.style.ATLAS)

# %%
mpl.histplot(out_hist, edges=[0, 150_000]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kyungeon/code/columnar_PHYSLITE_analyses/coffea2023_Zee_analysis.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Btop1/home/kyungeon/code/columnar_PHYSLITE_analyses/coffea2023_Zee_analysis.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> mpl.histplot(out_hist, edges=[0, 150_000]);
#
# NameError: name 'out_hist' is not defined

# %% [markdown]
# Shutdown dask cluster

# %%
client.close()
cluster.close()
